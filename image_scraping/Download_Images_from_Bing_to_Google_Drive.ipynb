# %% [markdown]
# ## Downloading Images from Bing and Saving them to Google Drive
#
# In this notebook, we download images from Bing Image Search and save them to Google Drive.

# %%
# !pip install bing-image-downloader
# Out:
# Requirement already satisfied: bing-image-downloader in /usr/local/lib/python3.10/dist-packages (1.1.2)

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
from pathlib import Path
import os
from bing_image_downloader import downloader
path = Path('/gdrive/MyDrive/art_recommendation')
os.listdir(path)
folder_path = path / 'Hieronymus_Bosch'

# %%
# try appending 'art', 'artwork', 'paintings', 'ouvre', 'works',
# 'famous paintings', 'less famous work', to your search

downloader.download("Hieronymus Bosch artworks", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60)
# Out:
# [%] Downloading Images to /gdrive/MyDrive/art_recommendation/Hieronymus_Bosch/Hieronymus Bosch artworks
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.artnews.com/wp-content/uploads/2020/04/5850813hm.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://1.bp.blogspot.com/-tzUOgAxcDzY/WjGSz10yLaI/AAAAAAAGAD4/WOAqCsmUACUWrRUL1xHRKZyKilX26MobgCLcBGAs/s1600/Hieronymus%2BBosch%2Bthe%2Bpedlar.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/6b/53/f1/6b53f111454826849b5baffeb72ff788.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.wga.hu/art/b/bosch/3garden/central/14centre.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/originals/b2/51/b4/b251b49cce12dac13a46ca7adefc21b6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://s-media-cache-ak0.pinimg.com/736x/f5/b2/2c/f5b22c8e6dc8dcd3757f49e6bbb420b3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://media.phillyvoice.com/media/images/Painting_by_Hieronymus_Bosch.2e16d0ba.fill-1200x630-c0.png
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://i.pinimg.com/originals/49/4a/8b/494a8baaa598aa0d8443508232ce1114.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://i.pinimg.com/736x/e7/1b/8d/e71b8df7ca6850043d9f99593635273f--hieronymus-bosch-renaissance-art.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://1.bp.blogspot.com/-t_mrjGLSJB0/WjGQ_zRrKPI/AAAAAAAGADU/aobqUjCCO6YM6vHxMMGZ48Vtx6MAYIUdgCLcBGAs/s1600/Hieronymus%2BBosch%2Bsaint%2Bjohn%2Bthe%2Bbaptist%2Bin%2Bthe%2Bdesert.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://eclecticlightdotcom.files.wordpress.com/2016/07/boschgardenearthlydelightscentowl1.jpg?w=1006
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://i.pinimg.com/originals/d5/04/9b/d5049b6b02240adeaf6c9c4d3263316c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://www.lambiek.net/artists/img/1021-78482-999-p2c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://i.pinimg.com/originals/9b/95/c7/9b95c79e1f68574498d38d016debcdb0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://i.pinimg.com/originals/3e/c0/67/3ec067337bb0af3a4f99f37614151ed6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://uploads3.wikiart.org/images/hieronymus-bosch/group-of-victims.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from http://uploads6.wikiart.org/images/hieronymus-bosch/not_detected_195354.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://2.bp.blogspot.com/-Lns47Rn_CDk/TmbLtefDD4I/AAAAAAAAFLQ/BAt-T5Tb-Oc/s1600/Hieronymus_Bosch%252C_Garden_of_Earthly_Delights_tryptich%252C_centre_panel_-_detail_6.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://i.pinimg.com/originals/16/bd/6e/16bd6e4fdc1bde73f9d005fe28b4ad48.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://wallpapercave.com/wp/wp8863699.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https
maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #63 from https://2.bp.blogspot.com/-NwQRIpykXUY/Wai0ydlwzLI/AAAAAAAAC6Y/MIYRK74bdG8JeKgrhrACDnISHxJEpaxjACLcBGAs/s1600/hieronymus%2Bbosch%2Bversuchung%2B2_jpg.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #64 from https://2.bp.blogspot.com/-vFKyhOZ4ylM/T2CBPyi1-qI/AAAAAAAA3ug/hClTSvyaIaA/s1600/Hieronymus_Bosch,_Garden_of_Earthly_Delights_tryptich,_centre_panel_-_detail_3.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #65 from https://en.wahooart.com/Art.nsf/O/7YZNJD/$File/Hieronymus-Bosch-Paradise-Ascent-of-the-Blessed.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #66 from https://cdn.dotcom.sothebys.psdops.com/dims4/default/acde475/2147483647/strip/true/crop/2000x1408+0+0/resize/684x482!/quality/90/?url=https:%2F%2Fcdn.dotcom.sothebys.psdops.com%2F04%2F08%2Fcdaaa68546e793e77611446b641c%2F096n09460-8mzpj.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #67 from https://s-media-cache-ak0.pinimg.com/originals/49/b1/3a/49b13a3b1f839c35546e7c9fb0322aa1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #68 from https://s-media-cache-ak0.pinimg.com/736x/ff/aa/64/ffaa644509c56d3bd204cd19f5ad895d--du-site-site-web.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #69 from https://blog.laemmle.com/wp-content/uploads/2016/07/Bosch-close-up-1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #70 from http://i2.cdn.turner.com/cnnnext/dam/assets/160217165124-hieronymous-21-super-169.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
# [%] Downloading Image #71 from https://2.bp.blogspot.com/-dQf9qzIKDpI/TmvXdDtMgdI/AAAAAAAABRw/bNA9yb0gt0A/s1600/Hieronymus-Bosch-Art-Last-Judgement.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 14
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 71 images.

# %%
os.listdir(folder_path)
# Out:
# ['Hieronymus Bosch paintings',
#  'Hieronymus Bosch artworks',
#  'Hieronymus Bosch artworks - the Visions of Tondal',
#  'Hieronymus Bosch artworks - the Garden of Earthly Delights']

# %%
from pathlib import Path
import shutil

# Define the source and destination directories
source_dir = folder_path
destination_dir = folder_path / 'paintings'

# Create the destination directory if it doesn't exist
destination_dir.mkdir(parents=True, exist_ok=True)

# Iterate through all subdirectories in the source directory
for subdir in source_dir.iterdir():
    if subdir.is_dir():
        # Iterate through all JPG files in each subdirectory
        for file in subdir.glob("*.jpg"):
            # Construct new file name with folder name as prefix
            new_file_name = f"{subdir.name}_{file.name}"
            new_file_path = destination_dir / new_file_name

            # Move and rename each file to the destination directory
            shutil.move(str(file), new_file_path)
